# %%
import pickle  as pkl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jobs_cleaned = pd.read_pickle('jobs_cleaned')

# %%
jobs_cleaned
# Out:
#       S.no.                                          Job Title  \
# 0         0  Data Analyst, Center on Immigration and Justic...
# 1         1                               Quality Data Analyst
# 2         2  Senior Data Analyst, Insights & Analytics Team...
# 3         3                                       Data Analyst
# 4         4                             Reporting Data Analyst
# ...     ...                                                ...
# 2247   2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2248   2249              Senior Data Analyst (Corporate Audit)
# 2249   2250  Technical Business Analyst (SQL, Data analytic...
# 2250   2251                Data Analyst 3, Customer Experience
# 2251   2252                        Senior Quality Data Analyst
#
#      Salary Estimate                                    Job Description  \
# 0            37K-66K  Are you eager to roll up your sleeves and harn...
# ...

# %%
fg  = sns.histplot(data=jobs_cleaned['avg_salary'],bins=10, kde=True)
for patch in fg.patches:
    height = patch.get_height()
    width = patch.get_width()
    fg.text(x=patch.get_x()+width/2,
                 y=height+10,
                 s=height,
                 ha='center')

# %%
jobs_cleaned.columns
# Out:
# Index(['S.no.', 'Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary'],
#       dtype='object')

# %%
jobs_cleaned['Job Title'].value_counts()
jobs_cleaned['Job Title'].nunique()
# Out:
# 1271

# %%
jobs_cleaned[jobs_cleaned['Job Title'].str.contains('data analyst', case=False)]
# Out:
#       S.no.                                          Job Title  \
# 0         0  Data Analyst, Center on Immigration and Justic...
# 1         1                               Quality Data Analyst
# 2         2  Senior Data Analyst, Insights & Analytics Team...
# 3         3                                       Data Analyst
# 4         4                             Reporting Data Analyst
# ...     ...                                                ...
# 2244   2245            Data Analyst Supporting the DEA #20-242
# 2246   2247  Marketing/Communications - Data Analyst-Marketing
# 2248   2249              Senior Data Analyst (Corporate Audit)
# 2250   2251                Data Analyst 3, Customer Experience
# 2251   2252                        Senior Quality Data Analyst
#
#      Salary Estimate                                    Job Description  \
# 0            37K-66K  Are you eager to roll up your sleeves and harn...
# ...

# %%
jobs_cleaned[jobs_cleaned['Job Title'].str.contains('sr data analyst',case=False)]['Job Title'].value_counts()
# Out:
# Job Title
# Sr Data Analyst                                                                9
# Sr Data Analyst for Customer Based Management                                  1
# Sr Data Analyst, Go-Live                                                       1
# Sr Data Analyst (DW)                                                           1
# Sr Data Analyst/Data Warehouse consultant with Financial Healthcare systems    1
# Sr Data Analyst II                                                             1
# Name: count, dtype: int64

# %%
jobs_cleaned[jobs_cleaned['Job Title'].str.contains('senior data analyst',case=False)].pivot_table(index='Job Title', aggfunc='count')

# %%
jobs_cleaned['Job Title'] = jobs_cleaned['Job Title'].replace(['Sr. Data Analyst','sr. data analyst', 'Sr Data Analyst', 'sr data analyst','senior data analyst', 'Senior Data Analyst', 'Data Analyst III', 'data analyst iii', 'senior data analyst'],'Senior Data Analyst', regex=True)

# %%
# most_common_data_jobs.reset_index()
# most_common_data_jobs.reset_index()
jobs_cleaned['job_title'] =jobs_cleaned['Job Title'].replace(['Data Analyst I', 'data analyst i', 'Data Analyst Junior', 'data analyst junior','Junior Data Analyst','Data Analyst Junior', 'Junior Data AnalystI', 'Junior Data Analystl'], 'Junior Data Analyst', regex=True)
jobs_cleaned['Job Title']= jobs_cleaned['Job Title'].replace('Data Analyst Junior', 'Junior Data Analyst', regex=True)  #  it was  missed

# %%
jobs_cleaned['Job Title'] = jobs_cleaned['Job Title'].replace(['Data Analyst II', 'data analyst ii', 'Middle Data Analyst'], 'Middle Data Analyst', regex=True)

# %%
most_common_data_jobs = jobs_cleaned['Job Title'].value_counts().nlargest(5).reset_index()
# most_common_data_jobs.reset_index()
most_common_data_jobs
# Out:
#                Job Title  count
# 0           Data Analyst    404
# 1    Senior Data Analyst    131
# 2    Junior Data Analyst     47
# 3  Business Data Analyst     28
# 4   Data Quality Analyst     17

# %%
jobs_cleaned[jobs_cleaned['Job Title']=='Data Analyst Junior']
# Out:
# Empty DataFrame
# Columns: [S.no., Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Type of ownership, Industry, Sector, Revenue, min_salary, max_salary, avg_salary, job_title]
# Index: []

# %%
plot = sns.barplot(data=most_common_data_jobs, x='Job Title', y='count')
plt.xticks(rotation=90)
for i in plot.patches:
    plt.text(i.get_x()+i.get_width()/4,i.get_height()+5, s = i.get_height())

# %%
jobs_cleaned = jobs_cleaned.drop('job_title', axis=1)

# %%
sns.boxenplot(data=jobs_cleaned, x='avg_salary')
plt.xlabel("Average Salary")
plt.ylabel("Count")
plt.title('Distribution of Average Salary')
plt.show()

# %%
jobs_cleaned['avg_salary']
# Out:
# 0       51500.0
# 1       51500.0
# 2       51500.0
# 3       51500.0
# 4       51500.0
#          ...
# 2247    91000.0
# 2248    91000.0
# 2249    91000.0
# 2250    91000.0
# 2251    91000.0
# Name: avg_salary, Length: 2251, dtype: float64

# %%
pd.to_pickle(jobs_cleaned, 'jobs_cleaned' )
